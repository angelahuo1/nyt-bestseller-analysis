# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../../db/nyt_books.db")

# %% [markdown]
# # 1. Row counts for reference.

# %%
pd.read_sql_query("SELECT COUNT(*) AS total_books FROM books;", conn)
# Out:
#    total_books
# 0         1366

# %%
pd.read_sql_query("SELECT COUNT(*) AS total_appearances FROM appearances;", conn)
# Out:
#    total_appearances
# 0               5775

# %% [markdown]
# # 2. Most frequent authors on the bestsellers list?

# %%
query = """
SELECT 
    b.author,
    COUNT(*) AS total_weeks,
    COUNT(DISTINCT a.list_date) AS unique_weeks,
    COUNT(DISTINCT b.title) AS unique_titles
FROM appearances a
JOIN books b ON a.isbn13 = b.isbn13
GROUP BY b.author
ORDER BY total_weeks DESC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                 author  total_weeks  unique_weeks  unique_titles
# 0       Rebecca Yarros          219           128              4
# 1         John Grisham          172           172             11
# 2         Stephen King          163           161             10
# 3          Delia Owens          134           134              1
# 4       David Baldacci          134           134             17
# 5       Danielle Steel          126           126             50
# 6            Matt Haig          111           111              2
# 7       Kristin Hannah          102            97              4
# 8        Bonnie Garmus           99            99              1
# 9      Nicholas Sparks           89            89              5
# 10    Elin Hilderbrand           80            80             11
# 11  Barbara Kingsolver           76            76              2
# 12    Alex Michaelides           69            69              3
# 13          Laura Dave           67            67              2
# 14     Shelby Van Pelt           64            64              1
# 15    Michael Connelly           61            61             10
# 16        Ann Patchett           56            56              2
# 17        Nora Roberts           55            55             15
# 18         V.E. Schwab           52            52              4
# 19    Percival Everett           52            52              1

# %% [markdown]
# # 3. Which publishers dominate the fiction bestsellers list?

# %%
query = """
SELECT
    b.publisher,
    COUNT(*) AS total_weeks,
    COUNT(DISTINCT b.title) AS unique_titles
FROM appearances a
JOIN books b ON a.isbn13 = b.isbn13
GROUP BY b.publisher
ORDER BY total_weeks DESC;
"""
pd.read_sql_query(query, conn)
# Out:
#                         publisher  total_weeks  unique_titles
# 0                   Little, Brown          483             95
# 1                       Doubleday          384             29
# 2                          Putnam          357             90
# 3                   Grand Central          305             65
# 4                    St. Martin's          264             68
# ..                            ...          ...            ...
# 115                Cemetery Dance            1              1
# 116                          Baen            1              1
# 117  Avid Reader/Simon & Schuster            1              1
# 118                         Amara            1              1
# 119                     Algonquin            1              1
#
# [120 rows x 3 columns]

# %% [markdown]
# # 4. Which books had the greatest longevity on the list?

# %%
query = """
SELECT
    b.title,
    b.author,
    MAX(a.weeks_on_list) AS peak_weeks
FROM appearances a
JOIN books b ON a.isbn13 = b.isbn13
GROUP BY b.isbn13
ORDER BY peak_weeks DESC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                                    title              author  peak_weeks
# 0                WHERE THE CRAWDADS SING         Delia Owens         134
# 1                   THE MIDNIGHT LIBRARY           Matt Haig         106
# 2                   LESSONS IN CHEMISTRY       Bonnie Garmus          99
# 3                            FOURTH WING      Rebecca Yarros          98
# 4                            FOURTH WING      Rebecca Yarros          94
# 5                        THE NIGHTINGALE      Kristin Hannah          87
# 6                             IRON FLAME      Rebecca Yarros          82
# 7                             IRON FLAME      Rebecca Yarros          79
# 8                       DEMON COPPERHEAD  Barbara Kingsolver          70
# 9                              THE WOMEN      Kristin Hannah          66
# 10             THE LAST THING HE TOLD ME          Laura Dave          65
# 11           REMARKABLY BRIGHT CREATURES     Shelby Van Pelt          64
# 12                 A GENTLEMAN IN MOSCOW         Amor Towles          59
# 13                    THE SILENT PATIENT    Alex Michaelides          56
# 14                  BEFORE WE WERE YOURS        Lisa Wingate          54
# 15                                 JAMES    Percival Everett          52
# 16  TOMORROW, AND TOMORROW, AND TOMORROW     Gabrielle Zevin          51
# 17                    THE VANISHING HALF        Brit Bennett          50
# 18               LITTLE FIRES EVERYWHERE          Celeste Ng          48
# 19     THE INVISIBLE LIFE OF ADDIE LARUE         V.E. Schwab          44

# %% [markdown]
# # 5. Which books hit #1 the fastest after debut?

# %%
query = """
WITH ranked AS (
    SELECT
        b.title,
        b.author,
        a.list_date,
        a.rank,
        ROW_NUMBER() OVER (PARTITION BY b.isbn13 ORDER BY a.list_date) AS first_week
    FROM appearances a
    JOIN books b ON a.isbn13 = b.isbn13
)
SELECT
    title,
    author,
    list_date AS date_hit_1,
    first_week AS week_number
FROM ranked
WHERE rank = 1
ORDER BY week_number ASC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                                  title                            author  \
# 0   THE NEXT PERSON YOU MEET IN HEAVEN                       Mitch Albom
# 1                               HEAT 2     Michael Mann and Meg Gardiner
# 2                      THE OTHER WOMAN                      Daniel Silva
# 3                         THE NEW GIRL                      Daniel Silva
# 4                            THE ORDER                      Daniel Silva
# 5         PORTRAIT OF AN UNKNOWN WOMAN                      Daniel Silva
# 6                          THE CELLIST                      Daniel Silva
# 7         THE STRANGER IN THE LIFEBOAT                       Mitch Albom
# 8                  THE PARIS APARTMENT                        Lucy Foley
# 9                                BABEL                        R.F. Kuang
# 10                           KATABASIS                        R.F. Kuang
# 11                 A DEATH IN CORNWALL                      Daniel Silva
# 12                       AN INSIDE JOB                      Daniel Silva
# 13                 THE HOTEL NANTUCKET                  Elin Hilderbrand
# 14               THE FIVE-STAR WEEKEND                  Elin Hilderbrand
# 15                           SWAN SONG                  Elin Hilderbrand
# 16            THE PRESIDENT IS MISSING  James Patterson and Bill Clinton
# 17                       SUMMER OF '69                  Elin Hilderbrand
# 18                          28 SUMMERS                  Elin Hilderbrand
# 19                         GOLDEN GIRL                  Elin Hilderbrand
#
#     date_hit_1  week_number
# 0   2018-10-28            1
# 1   2022-08-28            1
# 2   2018-08-05            1
# 3   2019-08-04            1
# 4   2020-08-02            1
# 5   2022-08-07            1
# 6   2021-08-01            1
# 7   2021-11-21            1
# 8   2022-03-13            1
# 9   2022-09-11            1
# 10  2025-09-14            1
# 11  2024-07-28            1
# 12  2025-08-03            1
# 13  2022-07-03            1
# 14  2023-07-02            1
# 15  2024-06-30            1
# 16  2018-07-15            1
# 17  2019-07-07            1
# 18  2020-07-05            1
# 19  2021-06-20            1

# %% [markdown]
# # 6. Which titles had the most volatile rank changes week-to-week?

# %%
query = """
WITH ordered AS (
    SELECT
        a.isbn13,
        b.title,
        b.author,
        a.list_date,
        a.rank,
        LAG(a.rank) OVER (PARTITION BY a.isbn13 ORDER BY a.list_date) AS prev_rank
    FROM appearances a
    JOIN books b ON a.isbn13 = b.isbn13
)
SELECT
    title,
    author,
    list_date,
    rank,
    prev_rank,
    (prev_rank - rank) AS rank_change
FROM ordered
WHERE prev_rank IS NOT NULL
ORDER BY ABS(rank_change) DESC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                                            title  \
# 0                                         HEAT 2
# 1                                          BABEL
# 2                          THE BOOK OF ELSEWHERE
# 3                          FOR RICHER FOR POORER
# 4   THE IRRESISTIBLE URGE TO FALL FOR YOUR ENEMY
# 5                               THE BUTCHER GAME
# 6                                  ONLY THE DEAD
# 7                        EVVIE DRAKE STARTS OVER
# 8                                     BLACK CAKE
# 9                                A MOTHER'S LOVE
# 10                                  THE BECOMING
# 11                               WHEN YOU SEE ME
# 12                              RED SKY MOURNING
# 13                                  CITY ON FIRE
# 14                                           JOY
# 15                              WE SOLVE MURDERS
# 16             THE INVISIBLE LIFE OF ADDIE LARUE
# 17                         THE COVENANT OF WATER
# 18                               FRAMED IN DEATH
# 19                               THE CANDY HOUSE
#
#                              author   list_date  rank  prev_rank  rank_change
# 0     Michael Mann and Meg Gardiner  2022-09-04    14          1          -13
# 1                        R.F. Kuang  2023-01-01    14          1          -13
# 2   Keanu Reeves and China Miéville  2024-08-18    15          2          -13
# 3                    Danielle Steel  2025-09-07    14          1          -13
# 4                Brigitte Knightley  2025-08-03    15          2          -13
# 5                   Alaina Urquhart  2024-10-13    14          1          -13
# 6                         Jack Carr  2023-06-11    14          1          -13
# 7                      Linda Holmes  2019-07-21     3         15           12
# 8               Charmaine Wilkerson  2022-02-27    14          2          -12
# 9                    Danielle Steel  2025-07-20    15          3          -12
# 10                     Nora Roberts  2021-12-19    14          2          -12
# 11                     Lisa Gardner  2020-02-23    15          3          -12
# 12                        Jack Carr  2024-07-14    13          1          -12
# 13                      Don Winslow  2022-05-22    14          3          -11
# 14                   Danielle Steel  2024-09-08    15          4          -11
# 15                    Richard Osman  2024-10-13    13          2          -11
# 16                      V.E. Schwab  2021-01-17     2         13           11
# 17                 Abraham Verghese  2024-05-12     4         15           11
# 18                        J.D. Robb  2025-10-05    14          3          -11
# 19                    Jennifer Egan  2022-05-01    15          4          -11

# %% [markdown]
# # 7. What seasonal trends exist in new book entries? When are most bestsellers debuting?

# %%
query = """
SELECT
    STRFTIME('%m', list_date) AS month,
    COUNT(*) AS new_entries
FROM (
    SELECT
        isbn13,
        MIN(list_date) AS list_date
    FROM appearances
    GROUP BY isbn13
)
GROUP BY month
ORDER BY month;
"""
pd.read_sql_query(query, conn)
# Out:
#    month  new_entries
# 0     01           55
# 1     02           82
# 2     03          125
# 3     04          106
# 4     05          124
# 5     06          119
# 6     07          108
# 7     08          111
# 8     09          155
# 9     10          183
# 10    11          126
# 11    12           72

# %% [markdown]
# # 8. What yearly trends exist in average weeks on the list? Is the market getting more competitive?

# %%
query = """
SELECT
    STRFTIME('%Y', list_date) AS year,
    AVG(weeks_on_list) AS avg_weeks
FROM appearances
GROUP BY year
ORDER BY year;
"""
pd.read_sql_query(query, conn)
# Out:
#    year  avg_weeks
# 0  2018   7.669333
# 1  2019   7.312821
# 2  2020  13.784615
# 3  2021  11.206410
# 4  2022  11.217949
# 5  2023  14.532075
# 6  2024  15.302564
# 7  2025  15.809929

# %% [markdown]
# # 9. What is market turnover like? How many new books enter the list each year?

# %%
query = """
SELECT
    STRFTIME('%Y', MIN(list_date)) AS year,
    COUNT(*) AS new_books
FROM appearances a
GROUP BY isbn13
ORDER BY year;
"""
pd.read_sql_query(query, conn)
# Out:
#       year  new_books
# 0     2018         12
# 1     2018          3
# 2     2018          1
# 3     2018          1
# 4     2018          1
# ...    ...        ...
# 1361  2025          1
# 1362  2025          1
# 1363  2025          4
# 1364  2025          1
# 1365  2025          8
#
# [1366 rows x 2 columns]

# %% [markdown]
# # 10. Which books debut the highest on the list?

# %%
query = """
WITH debut AS (
    SELECT
        b.title,
        b.author,
        MIN(a.list_date) AS debut_date,
        MIN(a.rank) AS debut_rank
    FROM appearances a
    JOIN books b ON a.isbn13 = b.isbn13
    GROUP BY b.isbn13
)
SELECT *
FROM debut
ORDER BY debut_rank ASC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                                  title                            author  \
# 0   THE NEXT PERSON YOU MEET IN HEAVEN                       Mitch Albom
# 1                               HEAT 2     Michael Mann and Meg Gardiner
# 2                      THE OTHER WOMAN                      Daniel Silva
# 3                         THE NEW GIRL                      Daniel Silva
# 4                            THE ORDER                      Daniel Silva
# 5         PORTRAIT OF AN UNKNOWN WOMAN                      Daniel Silva
# 6                          THE CELLIST                      Daniel Silva
# 7         THE STRANGER IN THE LIFEBOAT                       Mitch Albom
# 8                  THE PARIS APARTMENT                        Lucy Foley
# 9                                BABEL                        R.F. Kuang
# 10                           KATABASIS                        R.F. Kuang
# 11                            TOM LAKE                      Ann Patchett
# 12                 A DEATH IN CORNWALL                      Daniel Silva
# 13                       AN INSIDE JOB                      Daniel Silva
# 14                 THE HOTEL NANTUCKET                  Elin Hilderbrand
# 15               THE FIVE-STAR WEEKEND                  Elin Hilderbrand
# 16                           SWAN SONG                  Elin Hilderbrand
# 17            THE PRESIDENT IS MISSING  James Patterson and Bill Clinton
# 18                       SUMMER OF '69                  Elin Hilderbrand
# 19                          28 SUMMERS                  Elin Hilderbrand
#
#     debut_date  debut_rank
# 0   2018-10-28           1
# 1   2022-08-28           1
# 2   2018-08-05           1
# 3   2019-08-04           1
# 4   2020-08-02           1
# 5   2022-08-07           1
# 6   2021-08-01           1
# 7   2021-11-21           1
# 8   2022-03-13           1
# 9   2022-09-11           1
# 10  2025-09-14           1
# 11  2023-08-20           1
# 12  2024-07-28           1
# 13  2025-08-03           1
# 14  2022-07-03           1
# 15  2023-07-02           1
# 16  2024-06-30           1
# 17  2018-07-15           1
# 18  2019-07-07           1
# 19  2020-07-05           1

# %% [markdown]
# # 11. Which authors had repeat success on the list?

# %%
query = """
SELECT
    author,
    COUNT(DISTINCT title) AS total_titles,
    SUM(weeks_on_list) AS total_weeks
FROM books b
JOIN appearances a ON a.isbn13 = b.isbn13
GROUP BY author
HAVING total_titles >= 2
ORDER BY total_weeks DESC;
"""
pd.read_sql_query(query, conn)
# Out:
#                  author  total_titles  total_weeks
# 0        Rebecca Yarros             4         8996
# 1             Matt Haig             2         5686
# 2        Kristin Hannah             4         3092
# 3    Barbara Kingsolver             2         2506
# 4            Laura Dave             2         2148
# ..                  ...           ...          ...
# 244     Chris Bohjalian             2            2
# 245         Brent Weeks             2            2
# 246        Blake Crouch             2            2
# 247    Beatriz Williams             2            2
# 248    Adriana Trigiani             2            2
#
# [249 rows x 3 columns]

# %% [markdown]
# # 12. Which books had the most consistent popularity (least rank fluctuation)?

# %%
query = """
WITH diffs AS (
    SELECT
        a.isbn13,
        b.title,
        b.author,
        a.list_date,
        a.rank,
        LAG(rank) OVER (PARTITION BY a.isbn13 ORDER BY a.list_date) AS prev
    FROM appearances a
    JOIN books b ON a.isbn13 = b.isbn13
)
SELECT
    title,
    author,
    AVG(ABS(rank - prev)) AS avg_rank_change
FROM diffs
WHERE prev IS NOT NULL
GROUP BY isbn13
ORDER BY avg_rank_change ASC
LIMIT 20;
"""
pd.read_sql_query(query, conn)
# Out:
#                          title                            author  \
# 0           THE NIGHT WATCHMAN                    Louise Erdrich
# 1                   EXHALATION                        Ted Chiang
# 2   THE DEATH OF MRS. WESTAWAY                         Ruth Ware
# 3             THE HOUSE OF EVE                    Sadeqa Johnson
# 4                       WICKED                   Gregory Maguire
# 5         THE LAST HOUSE GUEST                     Megan Miranda
# 6              WILD DARK SHORE               Charlotte McConaghy
# 7               FIRST LIE WINS                     Ashley Elston
# 8               RUN, ROSE, RUN  Dolly Parton and James Patterson
# 9                  HAPPY PLACE                       Emily Henry
# 10                   THE WIDOW                      John Grisham
# 11           THE CORRESPONDENT                    Virginia Evans
# 12                  ALCHEMISED                          SenLinYu
# 13                   THE COVEN                   Harper L. Woods
# 14      SOMETHING IN THE WATER                Catherine Steadman
# 15   PRETTY BOYS ARE POISONOUS                         Megan Fox
# 16        THE PERFECT MARRIAGE                       Jeneva Rose
# 17                THE OUTSIDER                      Stephen King
# 18           SPARRING PARTNERS                      John Grisham
# 19         THE HOTEL NANTUCKET                  Elin Hilderbrand
#
#     avg_rank_change
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.333333
# 5          0.333333
# 6          0.500000
# 7          0.800000
# 8          0.875000
# 9          0.888889
# 10         1.000000
# 11         1.000000
# 12         1.000000
# 13         1.000000
# 14         1.000000
# 15         1.000000
# 16         1.000000
# 17         1.066667
# 18         1.083333
# 19         1.090909
